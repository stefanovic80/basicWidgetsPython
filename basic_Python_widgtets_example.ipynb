# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
display(HTML("<style>.prompt { display:none !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.output_result { max-width:100% !important; }</style>
# <style>.prompt { display:none !important; }</style>

# %%
import ipywidgets as widgets
from IPython.display import display
import numpy as np

# %%
import matplotlib.pyplot as plt
import matplotlib
#%matplotlib notebook
# %matplotlib nbagg

matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12) 
matplotlib.rc('figure', figsize=(9,7))

import warnings
warnings.filterwarnings('ignore')

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 14}

matplotlib.rc('font', **font)

# %% [markdown]
# $A = amplitude$
#
# $\phi = phase$
#
# $\nu = frequency$
#
# $A \sin(2\pi(\nu x + \phi))$

# %%
#https://www.youtube.com/watch?v=SN0Bflf14C4
x = np.linspace(0, 2, 1000)
fig, ax = plt.subplots(1, figsize = (9, 4) )
plt.suptitle('Sine wave')

def update_plot(amp, phase, freq):
    """
    this function is linked to the sliders and 
    it replots the sine wave when the sliders are changed
    """
    #----------------------------------------------------
    ax.clear()
    #----------------------------------------------------
    units = 'amp = {} $(psi)$  \nphase = {} $(s)$ \nfreq = {} $(Hz)$'
    y = amp * np.sin( 2*np.pi*( freq * x + phase ) )
    #----------------------------------------------------
    ax.plot(x, y, label = units.format(amp, phase, freq) )
    #----------------------------------------------------
    ax.legend(loc = 1 )
    ax.grid()
    ax.set_xlabel('$(s)$')
    ax.set_ylabel('$(psi)$')
    ax.set_xlim(x[0], x[-1])
    ax.set_ylim(-10, 10)
    plt.show()

    
amp = widgets.FloatSlider(min=1, max=10, value=1, description='Amp:')
phase = widgets.FloatSlider(min=0, max=5, value=0, description='Phase:')
freq = widgets.FloatSlider(min=1, max=10, value=1, description='Freq:')

#this line of code links the function with the bars
widgets.interactive(update_plot, amp = amp, phase = phase, freq = freq)
#display(amp, phase, freq)
# Out:
# <img src="data:image/png;base64,..." width="900">
# interactive(children=(FloatSlider(value=1.0, description='Amp:', max=10.0, min=1.0), FloatSlider(value=0.0, de…

# %% [markdown]
# <h1> That's a further example </h1>

# %%
import time
from ipywidgets import Layout

x = np.arange(-3, 3, 0.01)
y = np.sin(np.pi*x)/(np.pi*x)


fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.grid()
line, = ax2.plot(x, y)

def valueOnPlot(ux, uy):
    #legend.remove()
    legend, = ax2.plot([], [], label = 'x and y value are %f %f' %ux %uy, color = 'k')
    plt.legend(loc = 'upper right')
    plt.show()
    time.sleep(0.2)
    legend.remove()
    plt.show()

MinX = min(x)
MaxX = max(x)

MinY = min(y)
MaxY = max(y)
uy = widgets.FloatSlider(min=MinY, max=MaxY, value=MinY, description='exp: ', layout=Layout(width='650px'))
ux = widgets.FloatSlider(min=Min, max=Max, value=Min, description='exp: ', layout=Layout(width='650px'))
widgets.interactive(valueOnPlot, uy = uy, ux = ux);
uy
# Out:
# <img src="data:image/png;base64,..." width="900">
# FloatSlider(value=-0.21723353385844493, description='exp: ', layout=Layout(width='650px'), max=1.0, min=-0.217…
